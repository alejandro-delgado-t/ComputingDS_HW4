# %%
import sys
import os
cwd = os.getcwd()
src_path = os.path.abspath(os.path.join(cwd, '..', 'src'))
sys.path.append(src_path)

# %%
import pandas as pd
from model_function import load_data, split_train_test, remove_na, na_impute_mean, encode_ethnicity, binary_gender, train_model, predict, accuracy_sc, predict_probababilities, calc_roc_auc

# %%
## part a
df = load_data()


## part c
df = remove_na(df)


## part d
df = na_impute_mean(df)


## part e
df = encode_ethnicity(df)


## part f
df = binary_gender(df)

# %%
## part b
X_train, X_test, y_train, y_test = split_train_test(df)


## part g 
features_columns = ['age', 'height', 'weight', 'aids', 'cirrhosis', 'hepatic_failure', 'immunosuppression', 'leukemia', 'lymphoma', 'solid_tumor_with_metastasis']
X_train_select = X_train[features_columns]
X_test_select = X_test[features_columns]

model = train_model(X_train_select, y_train)


## part h
y_pred = predict(model, X_test_select)

accuracy = accuracy_sc(y_test, y_pred)
print(f'Accuracy score is: {accuracy:.4f}')

train_proba = predict_probababilities(model, X_train_select)
test_proba = predict_probababilities(model, X_test_select)
X_train['predict_train'] = train_proba
X_test['predict_test'] = test_proba

train_roc_auc = calc_roc_auc(model, X_train_select, y_train)
test_roc_auc = calc_roc_auc(model, X_test_select, y_test)


## print results
print("X_train dataset with predict_train column:")
display(X_train.head(5))
print("Predictions for train:")
display(pd.DataFrame(X_train[['predict_train']]).head(10))
print(f'Train ROC AUC: {train_roc_auc:.3f}')

print("X_test dataset with predict_test column:")
display(X_test.head(5))
print("Predictions for test:")
display(pd.DataFrame(X_test[['predict_test']]).head(10))
print(f'Test ROC AUC: {test_roc_auc:.3f}')
# Out:
# Accuracy score is: 0.7231
# X_train dataset with predict_train column:
#       encounter_id  hospital_id   age        bmi  elective_surgery  gender  \
# 3542        251680          118  84.0  24.103007                 1       1
# 9576        277808           74  89.0  23.900034                 0       0
# 7566        244385           83  50.0  33.550040                 1       0
# 4218        172420          118  85.0  28.767347                 0       1
# 6548        192399          118  62.0        NaN                 0       0
#
#       height hospital_admit_source           icu_admit_source  icu_id  ...  \
# 3542   165.1        Operating Room  Operating Room / Recovery      92  ...
# 9576   163.0  Emergency Department       Accident & Emergency     144  ...
# 7566   154.9        Operating Room  Operating Room / Recovery      95  ...
# 4218   175.0          Direct Admit       Accident & Emergency      97  ...
# 6548   167.6  Emergency Department       Accident & Emergency      97  ...
#
#      leukemia lymphoma  solid_tumor_with_metastasis  \
# 3542        0        0                            0
# 9576        0        0                            0
# 7566        0        0                            0
# 4218        0        0                            0
# 6548        0        0                            0
#
#       ethnicity_African American  ethnicity_Asian  ethnicity_Caucasian  \
# 3542                       False            False                 True
# 9576                       False            False                 True
# 7566                       False            False                 True
# 4218                       False            False                 True
# 6548                       False            False                 True
#
#       ethnicity_Hispanic  ethnicity_Native American  ethnicity_Other/Unknown  \
# 3542               False                      False                    False
# 9576               False                      False                    False
# 7566               False                      False                    False
# 4218               False                      False                    False
# 6548               False                      False                    False
#
#       predict_train
# 3542       0.080000
# 9576       0.020000
# 7566       0.080000
# 4218       0.060000
# 6548       0.468541
#
# [5 rows x 57 columns]
# Predictions for train:
#       predict_train
# 3542       0.080000
# 9576       0.020000
# 7566       0.080000
# 4218       0.060000
# 6548       0.468541
# 3875       0.240000
# 9300       0.720000
# 6285       0.120000
# 5347       0.030000
# 7731       0.020000
# Train ROC AUC: 0.998
# X_test dataset with predict_test column:
#       encounter_id  hospital_id   age        bmi  elective_surgery  gender  \
# 47          184214          151  59.0  14.844926                 0       0
# 3481        204727          118  74.0  37.884789                 1       1
# 8694        185576          168  78.0  24.798487                 0       0
# 2767        273468          118  59.0  23.906250                 0       1
# 3819        194682           69  58.0  26.386867                 0       1
#
#       height hospital_admit_source           icu_admit_source  icu_id  ...  \
# 47    170.20                 Floor                      Floor     109  ...
# 3481  188.00        Operating Room  Operating Room / Recovery     100  ...
# 8694  160.02  Emergency Department       Accident & Emergency     136  ...
# 2767  160.00                   NaN       Accident & Emergency      89  ...
# 3819  185.40  Emergency Department       Accident & Emergency      82  ...
#
#      leukemia lymphoma  solid_tumor_with_metastasis  \
# 47          0        0                            1
# 3481        0        0                            0
# 8694        0        0                            0
# 2767        0        0                            0
# 3819        0        0                            0
#
#       ethnicity_African American  ethnicity_Asian  ethnicity_Caucasian  \
# 47                          True            False                False
# 3481                       False            False                 True
# 8694                       False            False                 True
# 2767                       False             True                False
# 3819                       False            False                 True
#
#       ethnicity_Hispanic  ethnicity_Native American  ethnicity_Other/Unknown  \
# 47                 False                      False                    False
# 3481               False                      False                    False
# 8694               False                      False                    False
# 2767               False                      False                    False
# 3819               False                      False                    False
#
#       predict_test
# 47        0.130000
# 3481      0.610000
# 8694      0.020000
# 2767      0.040000
# 3819      0.066667
#
# [5 rows x 57 columns]
# Predictions for test:
#       predict_test
# 47        0.130000
# 3481      0.610000
# 8694      0.020000
# 2767      0.040000
# 3819      0.066667
# 9438      0.050000
# 2354      0.330000
# 71        0.096333
# 1996      0.480000
# 4533      0.120000
# Test ROC AUC: 0.616
